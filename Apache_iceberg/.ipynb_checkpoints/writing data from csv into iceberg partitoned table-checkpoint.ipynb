# %%
import os
import pyspark
from pyspark.sql import SparkSession

# %%
conf = (
    pyspark.SparkConf()
        .setAppName('app_name')
  		#packages 
        .set('spark.jars.packages', 'org.apache.iceberg:iceberg-spark-runtime-3.4_2.12:1.3.1,software.amazon.awssdk:bundle:2.17.178,software.amazon.awssdk:url-connection-client:2.17.178')
  		#SQL Extensions
        .set('spark.sql.extensions', 'org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions')
  		#Configuring Catalog
        .set('spark.sql.catalog.iceberg', 'org.apache.iceberg.spark.SparkCatalog')
        .set('spark.sql.catalog.iceberg.type', 'hadoop')
        .set('spark.sql.catalog.iceberg.warehouse', 'iceberg-warehouse')
)

# %%
## Start Spark Session
spark = SparkSession.builder.config(conf=conf).getOrCreate()
print("Spark Running")
# Out:
# :: loading settings :: url = jar:file:/opt/anaconda3/lib/python3.9/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/anshumanr/.ivy2/cache
# The jars for the packages stored in: /Users/anshumanr/.ivy2/jars
# org.apache.iceberg#iceberg-spark-runtime-3.4_2.12 added as a dependency
# software.amazon.awssdk#bundle added as a dependency
# software.amazon.awssdk#url-connection-client added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-240c95f1-7e58-4680-91f7-5d2bf796364f;1.0
# 	confs: [default]
# 	found org.apache.iceberg#iceberg-spark-runtime-3.4_2.12;1.3.1 in central
# 	found software.amazon.awssdk#bundle;2.17.178 in central
# 	found software.amazon.eventstream#eventstream;1.0.1 in central
# 	found software.amazon.awssdk#url-connection-client;2.17.178 in central
# 	found software.amazon.awssdk#utils;2.17.178 in central
# 	found org.reactivestreams#reactive-streams;1.0.3 in central
# 	found software.amazon.awssdk#annotations;2.17.178 in central
# 	found org.slf4j#slf4j-api;1.7.30 in local-m2-cache
# 	found software.amazon.awssdk#http-client-spi;2.17.178 in central
# 	found software.amazon.awssdk#metrics-spi;2.17.178 in central
# :: resolution report :: resolve 838ms :: artifacts dl 70ms
# 	:: modules in use:
# 	org.apache.iceberg#iceberg-spark-runtime-3.4_2.12;1.3.1 from central in [default]
# 	org.reactivestreams#reactive-streams;1.0.3 from central in [default]
# 	org.slf4j#slf4j-api;1.7.30 from local-m2-cache in [default]
# 	software.amazon.awssdk#annotations;2.17.178 from central in [default]
# 	software.amazon.awssdk#bundle;2.17.178 from central in [default]
# 	software.amazon.awssdk#http-client-spi;2.17.178 from central in [default]
# 	software.amazon.awssdk#metrics-spi;2.17.178 from central in [default]
# 	software.amazon.awssdk#url-connection-client;2.17.178 from central in [default]
# 	software.amazon.awssdk#utils;2.17.178 from central in [default]
# 	software.amazon.eventstream#eventstream;1.0.1 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   10  |   0   |   0   |   0   ||   10  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-240c95f1-7e58-4680-91f7-5d2bf796364f
# 	confs: [default]
# 	0 artifacts copied, 10 already retrieved (0kB/18ms)
# 23/08/11 18:09:19 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Spark Running

# %%
df=spark.read.format("csv").options(inferSchema='True',delimiter=',',header='True').load("/Users/anshumanr/Documents/Anime_Dataset/users-score-2023.csv")

# %%
spark.sql("create table iceberg.db.anime_users_score(user_id int,Username string,anime_id int,anime_title string,rating int) using iceberg partitioned by (anime_id)")
# Out:
# DataFrame[]

# %%
df = df.withColumn("rating", df["rating"].cast("int"))
df.write.mode("append").partitionBy("anime_id").saveAsTable("iceberg.db.anime_users_score", options={"write.parquet.page-row-limit": "100000"})

# %%
spark.sql("select * from iceberg.db.anime_users_score").show(1000)
# Out:
# +-------+----------------+--------+-------------+------+
# |user_id|        Username|anime_id|  anime_title|rating|
# +-------+----------------+--------+-------------+------+
# |     23|           Amuro|      26|   Texhnolyze|     4|
# |     48|            seif|      26|   Texhnolyze|     5|
# |     70|          Cruzle|      26|   Texhnolyze|     7|
# |    185|           Fador|      26|   Texhnolyze|     7|
# |    254|             Ayu|      26|   Texhnolyze|     2|
# |    271|          Divine|      26|   Texhnolyze|     6|
# |    282|           Hopis|      26|   Texhnolyze|     9|
# |    333|              db|      26|   Texhnolyze|     1|
# |    341|         melange|      26|   Texhnolyze|     9|
# |    344|          shance|      26|   Texhnolyze|     7|
# |    460|         Fehrant|      26|   Texhnolyze|     6|
# |    467|            June|      26|   Texhnolyze|     3|
# |    488|      stoneblade|      26|   Texhnolyze|     7|
# |    492|          Tasura|      26|   Texhnolyze|     8|
# |    504|   JusticeGundam|      26|   Texhnolyze|     9|
# |    509|             s2k|      26|   Texhnolyze|     9|
# |    560|            Kouy|      26|   Texhnolyze|    10|
# |    561|        Ishiyumi|      26|   Texhnolyze|     9|
# |    607|     Lord_Vegita|      26|   Texhnolyze|     4|
# |    614|   fluffyanimals|      26|   Texhnolyze|     7|
# |    618|             flo|      26|   Texhnolyze|     9|
# |    648|           Mumei|      26|   Texhnolyze|     7|
# |    652|            Wyko|      26|   Texhnolyze|     6|
# |    657|            Wind|      26|   Texhnolyze|     7|
# |    682|        zonnikku|      26|   Texhnolyze|     8|
# |    818|    caelanarcher|      26|   Texhnolyze|     6|
# |    827|       Chihaya__|      26|   Texhnolyze|    10|
# |    891|        majikkou|      26|   Texhnolyze|    10|
# |    903|             led|      26|   Texhnolyze|     9|
# |    962|          Crospi|      26|   Texhnolyze|     7|
# |   1008|    yukino031902|      26|   Texhnolyze|     7|
# |   1035|         budtske|      26|   Texhnolyze|     5|
# |   1079|        Trillian|      26|   Texhnolyze|     9|
# |   1105|         NayotaN|      26|   Texhnolyze|     8|
# |   1243|             Jin|      26|   Texhnolyze|     8|
# |   1272|   blushtimeblue|      26|   Texhnolyze|     6|
# |   1330|      endolphins|      26|   Texhnolyze|     7|
# |   1331|          Errawr|      26|   Texhnolyze|     4|
# |   1333|       ARoseCast|      26|   Texhnolyze|     6|
# |   1437|  Sense-Offender|      26|   Texhnolyze|     9|
# |   1475|        otaku515|      26|   Texhnolyze|     8|
# |   1531|   UnplugedZomby|      26|   Texhnolyze|    10|
# |   1559|            Kip_|      26|   Texhnolyze|     8|
# |   1568|         Ophelia|      26|   Texhnolyze|     5|
# |   1621|         Hachiko|      26|   Texhnolyze|     6|
# |   1629|           B00rz|      26|   Texhnolyze|     8|
# |   1640| RuthLovesKurama|      26|   Texhnolyze|     5|
# |   1728|         Linxmas|      26|   Texhnolyze|     8|
# |   1743|           Havoc|      26|   Texhnolyze|     7|
# |   1806|         gene___|      26|   Texhnolyze|     9|
# |   1813|         Aarikah|      26|   Texhnolyze|     2|
# |   1815|     carpeomnius|      26|   Texhnolyze|     8|
# |   1826|     otakuman706|      26|   Texhnolyze|     4|
# |   1835|            Kana|      26|   Texhnolyze|     8|
# |   1839|           Aridy|      26|   Texhnolyze|     6|
# |   1847|          Sylias|      26|   Texhnolyze|     6|
# |   1860|       sherlaira|      26|   Texhnolyze|     9|
# |   1901|  SY_IS_DEAD_IRL|      26|   Texhnolyze|     8|
# |   1916|       plastkaze|      26|   Texhnolyze|     2|
# |   1939|       Shinta2k1|      26|   Texhnolyze|     8|
# |   1940|            Biku|      26|   Texhnolyze|    10|
# |   1947|          jaalin|      26|   Texhnolyze|     5|
# |   1958|        Exaudias|      26|   Texhnolyze|     6|
# |   2001|        rusalkaz|      26|   Texhnolyze|    10|
# |   2010|           Pazzi|      26|   Texhnolyze|     6|
# |   2017|           Chili|      26|   Texhnolyze|    10|
# |   2026|     PhiloVaughn|      26|   Texhnolyze|     7|
# |   2043|        nekronos|      26|   Texhnolyze|     8|
# |   2051|      Gardouille|      26|   Texhnolyze|     9|
# |   2062|          kyoshi|      26|   Texhnolyze|     4|
# |   2069|       dizzygear|      26|   Texhnolyze|     9|
# |   2090|     ghostjacker|      26|   Texhnolyze|     8|
# |   2108|         Arakkis|      26|   Texhnolyze|     9|
# |   2136|        Despised|      26|   Texhnolyze|     8|
# |   2199|        AnimeNut|      26|   Texhnolyze|     9|
# |   2208|        cheatlog|      26|   Texhnolyze|    10|
# |   2220|         Ranivus|      26|   Texhnolyze|     4|
# |   2276|           Sitha|      26|   Texhnolyze|     7|
# |   2285|          Hexona|      26|   Texhnolyze|     7|
# |   2411|          WRYYYY|      26|   Texhnolyze|     6|
# |   2412|    vanofthedawn|      26|   Texhnolyze|     6|
# |   2513|      ShiniSenko|      26|   Texhnolyze|     6|
# |   2546|         OniNoKo|      26|   Texhnolyze|     9|
# |   2557| piecemealcranky|      26|   Texhnolyze|     7|
# |   2592|  penguinatorxl7|      26|   Texhnolyze|     8|
# |   2685|          Raijin|      26|   Texhnolyze|     9|
# |   2719|          Zephys|      26|   Texhnolyze|     6|
# |   2722|             Ris|      26|   Texhnolyze|     5|
# |   2749|         olebass|      26|   Texhnolyze|     9|
# |   2763|      Neverender|      26|   Texhnolyze|     9|
# |   2798|          thisis|      26|   Texhnolyze|     6|
# |   2807|        calaggie|      26|   Texhnolyze|     8|
# |   2810|       Mr_Doctor|      26|   Texhnolyze|    10|
# |   2844|        Lyrinoir|      26|   Texhnolyze|     8|
# |   2849|        Crimson_|      26|   Texhnolyze|     2|
# |   2872|          ssj2k4|      26|   Texhnolyze|     9|
# |   2876|        watchman|      26|   Texhnolyze|     7|
# |   2878|   Magickalcider|      26|   Texhnolyze|     8|
# |   2942|       PureWater|      26|   Texhnolyze|     8|
# |   3006|         destati|      26|   Texhnolyze|     7|
# |   3016|     Ginger_Snap|      26|   Texhnolyze|     7|
# |   3096|         Suzanoo|      26|   Texhnolyze|     8|
# |   3137|            S1LU|      26|   Texhnolyze|     5|
# |   3250|    nymphetamine|      26|   Texhnolyze|     5|
# |   3270|            Serj|      26|   Texhnolyze|     8|
# |   3278|         CEMPUNK|      26|   Texhnolyze|     4|
# |   3290|           nihil|      26|   Texhnolyze|     7|
# |   3363|   ElectricSlime|      26|   Texhnolyze|     5|
# |   3417|         Lainfan|      26|   Texhnolyze|     5|
# |   3418|          Mefist|      26|   Texhnolyze|     9|
# |   3428|    tainteddonut|      26|   Texhnolyze|     7|
# |   3582|      HobGadling|      26|   Texhnolyze|     9|
# |   3652|       minus-one|      26|   Texhnolyze|     8|
# |   3656|      starseeker|      26|   Texhnolyze|     9|
# |   3760|     Landstander|      26|   Texhnolyze|     5|
# |   3865|       MisseMisa|      26|   Texhnolyze|     8|
# |   3886|      mitamaking|      26|   Texhnolyze|     4|
# |   3887|          Najica|      26|   Texhnolyze|     6|
# |   3892|          Gothai|      26|   Texhnolyze|    10|
# |   4008|        RonTayan|      26|   Texhnolyze|    10|
# |   4035|         fatalis|      26|   Texhnolyze|     9|
# |   4044|          Gamall|      26|   Texhnolyze|     9|
# |   4140|        graywolf|      26|   Texhnolyze|     9|
# |   4150|          Liunee|      26|   Texhnolyze|     7|
# |   4178|          dbzcri|      26|   Texhnolyze|    10|
# |   4285|          pierro|      26|   Texhnolyze|     9|
# |   4327|           snork|      26|   Texhnolyze|     8|
# |   4344|       Darkanger|      26|   Texhnolyze|     7|
# |   4402|       Testament|      26|   Texhnolyze|     2|
# |   4407|          ExoDus|      26|   Texhnolyze|     6|
# |   4413|          Nines_|      26|   Texhnolyze|     8|
# |   4417|            TAoF|      26|   Texhnolyze|     7|
# |   4444|           dared|      26|   Texhnolyze|     7|
# |   4455|          Loosa2|      26|   Texhnolyze|     7|
# |   4483|        Zoisaite|      26|   Texhnolyze|     4|
# |   4506|         aeraeon|      26|   Texhnolyze|     7|
# |   4507|         Calau90|      26|   Texhnolyze|    10|
# |   4510|       BzzzYczeK|      26|   Texhnolyze|     8|
# |   4614|          gendo7|      26|   Texhnolyze|     9|
# |   4640|        LumCheng|      26|   Texhnolyze|    10|
# |   4654|         disgust|      26|   Texhnolyze|     9|
# |   4734|        RedGriff|      26|   Texhnolyze|     7|
# |   4737|           lepen|      26|   Texhnolyze|     7|
# |   4796|     WoodenJesus|      26|   Texhnolyze|     8|
# |   4813|           mauli|      26|   Texhnolyze|    10|
# |   4864|            me0w|      26|   Texhnolyze|     8|
# |   4866|          Raizen|      26|   Texhnolyze|     8|
# |   4951|      Cloudrayne|      26|   Texhnolyze|     8|
# |   4962|          asdfgh|      26|   Texhnolyze|     8|
# |   4979|    Jeff_J5Films|      26|   Texhnolyze|     8|
# |   4998|      tigeress02|      26|   Texhnolyze|     9|
# |   5004|      mochaholic|      26|   Texhnolyze|     7|
# |   5043|            Izzo|      26|   Texhnolyze|    10|
# |   5157|        Nemphtis|      26|   Texhnolyze|     7|
# |   5272|         FreaKaZ|      26|   Texhnolyze|    10|
# |   5352|           Maffy|      26|   Texhnolyze|     7|
# |   5363|   neko_chan1987|      26|   Texhnolyze|    10|
# |   5390|         cglennt|      26|   Texhnolyze|     9|
# |   5430|         Ilirith|      26|   Texhnolyze|     9|
# |   5478|             Orb|      26|   Texhnolyze|    10|
# |   5487|  TallonKarrde23|      26|   Texhnolyze|     3|
# |   5510|         harkins|      26|   Texhnolyze|     6|
# |   5518|          keule1|      26|   Texhnolyze|     9|
# |   5532|             Git|      26|   Texhnolyze|     8|
# |   5605|     s0ulreaper1|      26|   Texhnolyze|     1|
# |   5630|       Tachi-Kun|      26|   Texhnolyze|     7|
# |   5636|            tarf|      26|   Texhnolyze|     8|
# |   5653|        Akuma147|      26|   Texhnolyze|     8|
# |   5668|           jermy|      26|   Texhnolyze|     7|
# |   5682|          hitomi|      26|   Texhnolyze|     7|
# |   5703|       SquallAce|      26|   Texhnolyze|     8|
# |   5734|          ashura|      26|   Texhnolyze|     9|
# |   5738|         Dmikado|      26|   Texhnolyze|     6|
# |   5761|      Hraesvelgr|      26|   Texhnolyze|     8|
# |   5795|          Zexion|      26|   Texhnolyze|     5|
# |   5796|        lenquist|      26|   Texhnolyze|     8|
# |   5828|            Raja|      26|   Texhnolyze|     8|
# |   5862|    foreignlawns|      26|   Texhnolyze|     6|
# |   5900|           Cille|      26|   Texhnolyze|     8|
# |   5921|     smilerooney|      26|   Texhnolyze|     6|
# |   5924|       madhenriz|      26|   Texhnolyze|     9|
# |   5993|   WastingMyTime|      26|   Texhnolyze|     9|
# |   6104|          4anime|      26|   Texhnolyze|     7|
# |   6132|         alsotop|      26|   Texhnolyze|     2|
# |   6175|    vampires_key|      26|   Texhnolyze|     7|
# |   6176|      angelpoloo|      26|   Texhnolyze|    10|
# |   6181|           steam|      26|   Texhnolyze|    10|
# |   6188|       dumdeedum|      26|   Texhnolyze|    10|
# |   6195|       PFGrifter|      26|   Texhnolyze|     6|
# |   6264|          edwarx|      26|   Texhnolyze|     4|
# |   6325|      DeadlyRain|      26|   Texhnolyze|    10|
# |   6327|         winsome|      26|   Texhnolyze|     8|
# |   6382|      Marbmallow|      26|   Texhnolyze|     6|
# |   6446|     Lost_Number|      26|   Texhnolyze|    10|
# |   6449|      Ahojcookie|      26|   Texhnolyze|     6|
# |   6456|      MitchDaMan|      26|   Texhnolyze|     9|
# |   6480|     magentaanbu|      26|   Texhnolyze|     3|
# |   6486|iwatch2muchanime|      26|   Texhnolyze|     6|
# |   6508|        volition|      26|   Texhnolyze|     9|
# |   6612|           kdawg|      26|   Texhnolyze|     7|
# |   6624|          Fefedf|      26|   Texhnolyze|     7|
# |   6626|         Hiraoka|      26|   Texhnolyze|     8|
# |   6653|   lightningdean|      26|   Texhnolyze|     7|
# |   6694|   CowboyCadenza|      26|   Texhnolyze|     9|
# |   6703|         Fidelix|      26|   Texhnolyze|     8|
# |   6704|idiot_wallflower|      26|   Texhnolyze|     8|
# |   6788|           deem1|      26|   Texhnolyze|     7|
# |   6824|         dacedra|      26|   Texhnolyze|     4|
# |   6828|       Red_Devil|      26|   Texhnolyze|     8|
# |   6863|    Azure_Archer|      26|   Texhnolyze|     4|
# |   6919|  nervous_system|      26|   Texhnolyze|     9|
# |   6942|      Escheranko|      26|   Texhnolyze|     5|
# |   7058|         Phill-z|      26|   Texhnolyze|     2|
# |   7089|            loka|      26|   Texhnolyze|     8|
# |   7164|     storyteller|      26|   Texhnolyze|     7|
# |   7180|        Sulieman|      26|   Texhnolyze|     6|
# |   7227|    Portaljacker|      26|   Texhnolyze|     3|
# |   7231|         Axersia|      26|   Texhnolyze|    10|
# |   7258|  Ghostlibrarian|      26|   Texhnolyze|     5|
# |   7320|          Phil10|      26|   Texhnolyze|     7|
# |   7341|    SamantaBlack|      26|   Texhnolyze|     7|
# |   7356|     Ferentarius|      26|   Texhnolyze|     9|
# |   7360|    FullMetal628|      26|   Texhnolyze|     8|
# |   7370|         Sykotic|      26|   Texhnolyze|     8|
# |   7387|            One_|      26|   Texhnolyze|     4|
# |   7410|          SM4DAR|      26|   Texhnolyze|     7|
# |   7453|        weirdo90|      26|   Texhnolyze|     6|
# |   7471|      Nagebelmok|      26|   Texhnolyze|     8|
# |   7487|            Dima|      26|   Texhnolyze|    10|
# |   7496|      Tem-Inburn|      26|   Texhnolyze|     6|
# |   7503|          Foxsym|      26|   Texhnolyze|    10|
# |   7526|       Selerious|      26|   Texhnolyze|     4|
# |   7535|        madeener|      26|   Texhnolyze|     8|
# |   7552|            hest|      26|   Texhnolyze|     9|
# |   7625|     GetInTheVan|      26|   Texhnolyze|     9|
# |   7638|         Sorarin|      26|   Texhnolyze|     7|
# |   7643|        Shinji90|      26|   Texhnolyze|     8|
# |   7660|            m4kc|      26|   Texhnolyze|     9|
# |   7773|           Nande|      26|   Texhnolyze|     4|
# |   7815|      Napalmitos|      26|   Texhnolyze|     6|
# |   7867|            zeni|      26|   Texhnolyze|     9|
# |   7908|             clc|      26|   Texhnolyze|     7|
# |   7916|            lynx|      26|   Texhnolyze|     7|
# |   8041|        GoodSoft|      26|   Texhnolyze|     9|
# |   8132|           Chued|      26|   Texhnolyze|    10|
# |   8166|      MadModderX|      26|   Texhnolyze|     6|
# |   8204|           Teemu|      26|   Texhnolyze|     5|
# |   8218|         Instant|      26|   Texhnolyze|     7|
# |   8264|          Sephix|      26|   Texhnolyze|     6|
# |   8300|            EPDJ|      26|   Texhnolyze|     4|
# |   8320|      hatemonkey|      26|   Texhnolyze|     8|
# |   8346|ExplodeySquirrel|      26|   Texhnolyze|     5|
# |   8401|        shoganai|      26|   Texhnolyze|     5|
# |   8429|          event_|      26|   Texhnolyze|     8|
# |   8509|         dokikun|      26|   Texhnolyze|    10|
# |   8517| DisplayName-__-|      26|   Texhnolyze|     9|
# |   8551|          Samuca|      26|   Texhnolyze|     8|
# |   8567|       Madhatter|      26|   Texhnolyze|     8|
# |   8584|         Caboose|      26|   Texhnolyze|     3|
# |   8611|     TheWestExit|      26|   Texhnolyze|    10|
# |   8856|         falchie|      26|   Texhnolyze|     6|
# |   8863| killah_koolaide|      26|   Texhnolyze|     7|
# |   8882|        edwassas|      26|   Texhnolyze|     8|
# |   8900|       Spiricore|      26|   Texhnolyze|    10|
# |   8936|      MilhouseX8|      26|   Texhnolyze|     7|
# |   8949|bio-boosted-kite|      26|   Texhnolyze|     4|
# |   8991|        tungwene|      26|   Texhnolyze|     3|
# |   9059|         slash17|      26|   Texhnolyze|     9|
# |   9063|          Eredir|      26|   Texhnolyze|     9|
# |   9112|     ShadowBladE|      26|   Texhnolyze|     7|
# |   9171|     LoveMonster|      26|   Texhnolyze|     6|
# |   9200|          necrop|      26|   Texhnolyze|     7|
# |   9212|     unholyghost|      26|   Texhnolyze|     8|
# |   9231| Dikard_von_Doom|      26|   Texhnolyze|     8|
# |   9288|         Gladius|      26|   Texhnolyze|     7|
# |   9322|        acucar11|      26|   Texhnolyze|     7|
# |   9357|           IgorS|      26|   Texhnolyze|     4|
# |   9361|           Areku|      26|   Texhnolyze|     7|
# |   9362|         Xuchiel|      26|   Texhnolyze|    10|
# |   9412|          _edge_|      26|   Texhnolyze|     8|
# |   9434|             Rem|      26|   Texhnolyze|     7|
# |   9498|             Evo|      26|   Texhnolyze|     9|
# |   9509|         Aerith_|      26|   Texhnolyze|     8|
# |   9685|   Yuki-na-no-da|      26|   Texhnolyze|     2|
# |   9705|             mim|      26|   Texhnolyze|     9|
# |   9730|          Kyou__|      26|   Texhnolyze|     4|
# |   9734|       kaszak696|      26|   Texhnolyze|     9|
# |   9766|  aurevoirpeyton|      26|   Texhnolyze|     7|
# |   9819|    FabriAyanami|      26|   Texhnolyze|     5|
# |   9882|  jakobtheliar12|      26|   Texhnolyze|     8|
# |   9896|      yukisama69|      26|   Texhnolyze|     8|
# |   9981|      kidsmoke91|      26|   Texhnolyze|    10|
# |  10012|      Sora_Zelse|      26|   Texhnolyze|    10|
# |  10026|    xxkiriyamaxx|      26|   Texhnolyze|     3|
# |  10105|    computerheat|      26|   Texhnolyze|     7|
# |  10106|            Hias|      26|   Texhnolyze|     7|
# |  10120|          -SeRg-|      26|   Texhnolyze|     8|
# |  10268|           Xavan|      26|   Texhnolyze|     7|
# |  10344|       LonginusX|      26|   Texhnolyze|     6|
# |  10403|        fuyoalbi|      26|   Texhnolyze|     6|
# |  10422|           kuma-|      26|   Texhnolyze|     7|
# |  10432|            _ktx|      26|   Texhnolyze|     8|
# |  10488|     BunnyBomber|      26|   Texhnolyze|     8|
# |  10655|            Arya|      26|   Texhnolyze|    10|
# |  10686|     chaos_flare|      26|   Texhnolyze|     7|
# |  10696|   The_Elemental|      26|   Texhnolyze|     6|
# |  10719|          _alive|      26|   Texhnolyze|     9|
# |  10732|         Symbian|      26|   Texhnolyze|     8|
# |  10814|       DeepBrook|      26|   Texhnolyze|     7|
# |  10917|          Katja-|      26|   Texhnolyze|     7|
# |  10947|           kaspi|      26|   Texhnolyze|     8|
# |  10956|          Korvis|      26|   Texhnolyze|     7|
# |  11100|         Matsuri|      26|   Texhnolyze|     1|
# |  11131|       TenroK001|      26|   Texhnolyze|     7|
# |  11166|        Kuzapura|      26|   Texhnolyze|    10|
# |  11232|    l0rdBradf0rd|      26|   Texhnolyze|     9|
# |  11288|      GhostShell|      26|   Texhnolyze|     5|
# |  11347|   Tunnel-Lights|      26|   Texhnolyze|     8|
# |  11358|         DzyxAsZ|      26|   Texhnolyze|     8|
# |  11454|         szklany|      26|   Texhnolyze|     9|
# |  11472|        Talhkora|      26|   Texhnolyze|     8|
# |  11474|          bugeol|      26|   Texhnolyze|     8|
# |  11495|        1______1|      26|   Texhnolyze|     8|
# |  11502|   the_seventh_l|      26|   Texhnolyze|    10|
# |  11506|        lnemesis|      26|   Texhnolyze|    10|
# |  11532|        BlackKyo|      26|   Texhnolyze|     8|
# |  11534|            M2k3|      26|   Texhnolyze|     3|
# |  11535|           zippy|      26|   Texhnolyze|     6|
# |  11709|           Kaeki|      26|   Texhnolyze|     6|
# |  11742|        johnnski|      26|   Texhnolyze|    10|
# |  11827|Chevalier_Schiff|      26|   Texhnolyze|     7|
# |  11853|         Skull26|      26|   Texhnolyze|     9|
# |  11866|           Boogy|      26|   Texhnolyze|     7|
# |  11879|       MrSanjuro|      26|   Texhnolyze|     6|
# |  11883|        sin22eze|      26|   Texhnolyze|     7|
# |  11896|       Ratmaniac|      26|   Texhnolyze|     9|
# |  11982|          drklrd|      26|   Texhnolyze|     9|
# |  12041|        Karasu87|      26|   Texhnolyze|     7|
# |  12051|         Hypnall|      26|   Texhnolyze|     8|
# |  12070|           Lunch|      26|   Texhnolyze|     9|
# |  12267| mommyslttlmnstr|      26|   Texhnolyze|     4|
# |  12291|         Slander|      26|   Texhnolyze|     8|
# |  12302|          Arelym|      26|   Texhnolyze|     7|
# |  12306|          Vilbel|      26|   Texhnolyze|     8|
# |  12317|       konou_ken|      26|   Texhnolyze|     9|
# |  12328|           HacKi|      26|   Texhnolyze|     9|
# |  12423|            Joot|      26|   Texhnolyze|     9|
# |  12473|         Telnari|      26|   Texhnolyze|     7|
# |  12486|        johnlolo|      26|   Texhnolyze|     8|
# |  12501|   Ravenshadow79|      26|   Texhnolyze|     7|
# |  12525|      Telocvovim|      26|   Texhnolyze|     9|
# |  12541| AbjectifiedIzzy|      26|   Texhnolyze|     8|
# |  12562|     Phoenicurus|      26|   Texhnolyze|     7|
# |  12580|      Chibi_Goku|      26|   Texhnolyze|     7|
# |  12600|      kramasanas|      26|   Texhnolyze|     8|
# |  12616|      greendogod|      26|   Texhnolyze|     9|
# |  12654|             Baa|      26|   Texhnolyze|    10|
# |  12684|  Hellsing_lover|      26|   Texhnolyze|     9|
# |  12699|    MercuryLampe|      26|   Texhnolyze|     5|
# |  12734|       kurokurai|      26|   Texhnolyze|     7|
# |  12761|  TheObscurePoet|      26|   Texhnolyze|     7|
# |  12813|         Ariadna|      26|   Texhnolyze|     8|
# |  12865|    WingZero1223|      26|   Texhnolyze|     7|
# |  12994|          Kiraly|      26|   Texhnolyze|     4|
# |  13003|            acro|      26|   Texhnolyze|    10|
# |  13008|           Detri|      26|   Texhnolyze|     6|
# |  13056|      mantzikert|      26|   Texhnolyze|     9|
# |  13059|         Statler|      26|   Texhnolyze|     8|
# |  13091|   TakeshiKitano|      26|   Texhnolyze|     6|
# |  13203|     Rahkshilord|      26|   Texhnolyze|     4|
# |     48|            seif|      27|Trinity Blood|     7|
# |     72|         james2k|      27|Trinity Blood|     7|
# |     81|            Ramp|      27|Trinity Blood|     8|
# |    119|          Phony2|      27|Trinity Blood|    10|
# |    133|         Ritsuka|      27|Trinity Blood|     7|
# |    138|     DanskiJonez|      27|Trinity Blood|    10|
# |    208|     Arinohyoshi|      27|Trinity Blood|     9|
# |    224|         modious|      27|Trinity Blood|     8|
# |    254|             Ayu|      27|Trinity Blood|     8|
# |    258|             Zan|      27|Trinity Blood|    10|
# |    297|            Muda|      27|Trinity Blood|     8|
# |    333|              db|      27|Trinity Blood|     3|
# |    346|         zbarron|      27|Trinity Blood|     9|
# |    376|      s0kkiplast|      27|Trinity Blood|     7|
# |    384|             Rie|      27|Trinity Blood|     9|
# |    399|           roarg|      27|Trinity Blood|     7|
# |    401|          zylias|      27|Trinity Blood|     7|
# |    407|        KingKogs|      27|Trinity Blood|     9|
# |    417|      virusmyrus|      27|Trinity Blood|     8|
# |    426|       cnsgurl23|      27|Trinity Blood|    10|
# |    431|         izikiel|      27|Trinity Blood|     8|
# |    434|       Gaignun87|      27|Trinity Blood|     7|
# |    436|         Katsuki|      27|Trinity Blood|     7|
# |    460|         Fehrant|      27|Trinity Blood|     7|
# |    462|    UndyingQueen|      27|Trinity Blood|     8|
# |    465|          bloody|      27|Trinity Blood|     7|
# |    467|            June|      27|Trinity Blood|     6|
# |    476|     TheRedSpade|      27|Trinity Blood|     7|
# |    480|            Sync|      27|Trinity Blood|     7|
# |    488|      stoneblade|      27|Trinity Blood|     8|
# |    506|      Expression|      27|Trinity Blood|     5|
# |    512|       Champloon|      27|Trinity Blood|     9|
# |    514|    MarzipanNeko|      27|Trinity Blood|     7|
# |    527|   wildinferno16|      27|Trinity Blood|     9|
# |    545|       mugiwara-|      27|Trinity Blood|     7|
# |    558|      zanmato666|      27|Trinity Blood|     7|
# |    561|        Ishiyumi|      27|Trinity Blood|     9|
# |    609|           Canal|      27|Trinity Blood|     6|
# |    615|          Yojiro|      27|Trinity Blood|     7|
# |    618|             flo|      27|Trinity Blood|     7|
# |    651|           Artic|      27|Trinity Blood|     6|
# |    657|            Wind|      27|Trinity Blood|     9|
# |    658|         Gemelle|      27|Trinity Blood|    10|
# |    678|   CrimsonKnight|      27|Trinity Blood|     7|
# |    695|      linoleumxx|      27|Trinity Blood|     2|
# |    701|  ShikiYukishiro|      27|Trinity Blood|     9|
# |    728|          Wickio|      27|Trinity Blood|     8|
# |    736|DistinctlyBenign|      27|Trinity Blood|     7|
# |    747|            soyo|      27|Trinity Blood|     5|
# |    748|         Rosebud|      27|Trinity Blood|     6|
# |    749|          AmiYuy|      27|Trinity Blood|     7|
# |    757|          Cidfan|      27|Trinity Blood|     4|
# |    766|         Locrian|      27|Trinity Blood|     8|
# |    776|           lecor|      27|Trinity Blood|     8|
# |    787|     kimodameshi|      27|Trinity Blood|     8|
# |    815|         Bobbert|      27|Trinity Blood|     8|
# |    817|       AKIO-NOIR|      27|Trinity Blood|     7|
# |    818|    caelanarcher|      27|Trinity Blood|     7|
# |    854|             Z0C|      27|Trinity Blood|    10|
# |    859|         Sora_Li|      27|Trinity Blood|     9|
# |    870|     irisnemesis|      27|Trinity Blood|     7|
# |    903|             led|      27|Trinity Blood|     9|
# |    912|         Keiyori|      27|Trinity Blood|     8|
# |    916| thesundaywriter|      27|Trinity Blood|     6|
# |    926|  thepinkavenger|      27|Trinity Blood|    10|
# |    928|      macskeptic|      27|Trinity Blood|     5|
# |    935|        diordiah|      27|Trinity Blood|     5|
# |    945| BulletproofSoul|      27|Trinity Blood|     8|
# |    949|      chocopocky|      27|Trinity Blood|     7|
# |    962|          Crospi|      27|Trinity Blood|     8|
# |    966|        shoalkip|      27|Trinity Blood|     6|
# |    981|        Shadow__|      27|Trinity Blood|     5|
# |    986|      Vagaryhexx|      27|Trinity Blood|     8|
# |    987|    silmarwen_85|      27|Trinity Blood|     8|
# |    988|          Hirako|      27|Trinity Blood|     7|
# |    989|          Virems|      27|Trinity Blood|     9|
# |    998|           Sanna|      27|Trinity Blood|     8|
# |   1014|         shinobs|      27|Trinity Blood|     8|
# |   1019|    animeangel90|      27|Trinity Blood|     9|
# |   1032|     dark7ammood|      27|Trinity Blood|     8|
# |   1068| mrfunkybawkbawk|      27|Trinity Blood|     6|
# |   1072|            ZJun|      27|Trinity Blood|     7|
# |   1077|          Kottie|      27|Trinity Blood|     7|
# |   1079|        Trillian|      27|Trinity Blood|     7|
# |   1080|         herakoz|      27|Trinity Blood|     9|
# |   1081|      sniper_ram|      27|Trinity Blood|     8|
# |   1111|       yahiko200|      27|Trinity Blood|     9|
# |   1113|         Kuwaiti|      27|Trinity Blood|     7|
# |   1144|         ScottyC|      27|Trinity Blood|     8|
# |   1150|       ivorykeys|      27|Trinity Blood|    10|
# |   1162|           piuxu|      27|Trinity Blood|     9|
# |   1172|        Xzorcist|      27|Trinity Blood|     6|
# |   1188|          tartol|      27|Trinity Blood|     8|
# |   1196| imgonnatakeurcd|      27|Trinity Blood|     7|
# |   1197|       ipsofacto|      27|Trinity Blood|     7|
# |   1243|             Jin|      27|Trinity Blood|     5|
# |   1268|        solarius|      27|Trinity Blood|     8|
# |   1272|   blushtimeblue|      27|Trinity Blood|     6|
# |   1280|      Flash-hack|      27|Trinity Blood|    10|
# |   1286|         RuneYue|      27|Trinity Blood|     5|
# |   1293|      GeneralCox|      27|Trinity Blood|     6|
# |   1301|        Ephermal|      27|Trinity Blood|    10|
# |   1313|           windy|      27|Trinity Blood|     4|
# |   1330|      endolphins|      27|Trinity Blood|     6|
# |   1331|          Errawr|      27|Trinity Blood|     8|
# |   1371|     Cytoplasmic|      27|Trinity Blood|     5|
# |   1386|   lord_heinrich|      27|Trinity Blood|     7|
# |   1395|         Voidist|      27|Trinity Blood|     6|
# |   1400|      Gaia_Vedai|      27|Trinity Blood|    10|
# |   1419|     blackice119|      27|Trinity Blood|     8|
# |   1420|            x10a|      27|Trinity Blood|    10|
# |   1425|        BlueHaro|      27|Trinity Blood|     7|
# |   1432|          Dragos|      27|Trinity Blood|     5|
# |   1434|      TMcMahon51|      27|Trinity Blood|     8|
# |   1439|     andresonego|      27|Trinity Blood|     7|
# |   1453|        VyraLove|      27|Trinity Blood|     9|
# |   1454|        Portugas|      27|Trinity Blood|     5|
# |   1467|         firecry|      27|Trinity Blood|     8|
# |   1470|         Azrael8|      27|Trinity Blood|     7|
# |   1471|        muaddib_|      27|Trinity Blood|    10|
# |   1475|        otaku515|      27|Trinity Blood|     8|
# |   1483|     drastikhate|      27|Trinity Blood|    10|
# |   1491|        Sanguine|      27|Trinity Blood|     5|
# |   1492|        fleshcut|      27|Trinity Blood|     7|
# |   1493|        cheng101|      27|Trinity Blood|     6|
# |   1514|          wraith|      27|Trinity Blood|     8|
# |   1519|       wretchedx|      27|Trinity Blood|     8|
# |   1525|           htt2k|      27|Trinity Blood|     6|
# |   1537|            Naku|      27|Trinity Blood|     6|
# |   1554|         GokuH12|      27|Trinity Blood|     7|
# |   1568|         Ophelia|      27|Trinity Blood|     6|
# |   1585|    fallen_angel|      27|Trinity Blood|     7|
# |   1613|         Chocobo|      27|Trinity Blood|     6|
# |   1620|       Taichi_EX|      27|Trinity Blood|     8|
# |   1625|        ssisnake|      27|Trinity Blood|     6|
# |   1634|          omerby|      27|Trinity Blood|     8|
# |   1640| RuthLovesKurama|      27|Trinity Blood|     9|
# |   1667|          karasu|      27|Trinity Blood|     7|
# |   1670|        Trunkz0r|      27|Trinity Blood|     6|
# |   1691|      anderology|      27|Trinity Blood|     7|
# |   1696|         Miyarin|      27|Trinity Blood|     8|
# |   1717|  Twitchy_Fingah|      27|Trinity Blood|     9|
# |   1742|             Mgz|      27|Trinity Blood|     9|
# |   1787|         TheGort|      27|Trinity Blood|     5|
# |   1807|     Sailorsolar|      27|Trinity Blood|     5|
# |   1813|         Aarikah|      27|Trinity Blood|     7|
# |   1815|     carpeomnius|      27|Trinity Blood|     7|
# |   1841|     Sora-Senpai|      27|Trinity Blood|     8|
# |   1849|      sluttyukes|      27|Trinity Blood|     8|
# |   1856|             LZX|      27|Trinity Blood|     7|
# |   1869|        infinity|      27|Trinity Blood|     8|
# |   1873|       WolfElf87|      27|Trinity Blood|    10|
# |   1877|        Haohmaru|      27|Trinity Blood|     8|
# |   1897|      xkamikazex|      27|Trinity Blood|     7|
# |   1901|  SY_IS_DEAD_IRL|      27|Trinity Blood|     3|
# |   1907|     kakashidiot|      27|Trinity Blood|     9|
# |   1916|       plastkaze|      27|Trinity Blood|     7|
# |   1918| murasaki_pantsu|      27|Trinity Blood|     7|
# |   1945|          kyorue|      27|Trinity Blood|     9|
# |   1957|         Karedis|      27|Trinity Blood|     3|
# |   1959|            senn|      27|Trinity Blood|     8|
# |   1962|             Don|      27|Trinity Blood|     9|
# |   1966|         Utellme|      27|Trinity Blood|     8|
# |   1969|          Ragnao|      27|Trinity Blood|     5|
# |   1979|          skygtr|      27|Trinity Blood|     2|
# |   1984|        Belzenef|      27|Trinity Blood|     7|
# |   1988|     Parsalian27|      27|Trinity Blood|     9|
# |   2001|        rusalkaz|      27|Trinity Blood|     9|
# |   2005|  xeroxedechidna|      27|Trinity Blood|     8|
# |   2017|           Chili|      27|Trinity Blood|     6|
# |   2025|            n924|      27|Trinity Blood|     5|
# |   2026|     PhiloVaughn|      27|Trinity Blood|     5|
# |   2031| princeofpirates|      27|Trinity Blood|     5|
# |   2038|        MaryBell|      27|Trinity Blood|     8|
# |   2040|    swatassassin|      27|Trinity Blood|    10|
# |   2051|      Gardouille|      27|Trinity Blood|     9|
# |   2060|        Sublimit|      27|Trinity Blood|     4|
# |   2094|         Trinpie|      27|Trinity Blood|     6|
# |   2096|      Jin-Kazama|      27|Trinity Blood|     8|
# |   2104|          Tydfil|      27|Trinity Blood|     8|
# |   2108|         Arakkis|      27|Trinity Blood|     1|
# |   2129|         argon30|      27|Trinity Blood|     7|
# |   2134|            Zeth|      27|Trinity Blood|     8|
# |   2136|        Despised|      27|Trinity Blood|     8|
# |   2140|     TeenTitan85|      27|Trinity Blood|     9|
# |   2144|   panzer_magier|      27|Trinity Blood|     6|
# |   2150|           Kaero|      27|Trinity Blood|     8|
# |   2158| evolutionrefrag|      27|Trinity Blood|     7|
# |   2170|       DrkSasuke|      27|Trinity Blood|    10|
# |   2184|           Zirgo|      27|Trinity Blood|     8|
# |   2196|        jamin_za|      27|Trinity Blood|     7|
# |   2208|        cheatlog|      27|Trinity Blood|     9|
# |   2211|            Synn|      27|Trinity Blood|    10|
# |   2220|         Ranivus|      27|Trinity Blood|     5|
# |   2223|           alord|      27|Trinity Blood|     6|
# |   2234|           vocab|      27|Trinity Blood|     5|
# |   2241| MeHeartGungrave|      27|Trinity Blood|     8|
# |   2247|      coralphine|      27|Trinity Blood|     9|
# |   2252|   indienerdisme|      27|Trinity Blood|     6|
# |   2275|         Xelinis|      27|Trinity Blood|     4|
# |   2299|      Gravskopan|      27|Trinity Blood|     6|
# |   2300|          Ze66oX|      27|Trinity Blood|     7|
# |   2310|        biscotti|      27|Trinity Blood|     8|
# |   2324|   kirAth-shiAue|      27|Trinity Blood|     6|
# |   2345|      boxcarpoet|      27|Trinity Blood|     8|
# |   2347|        Dracoowl|      27|Trinity Blood|     8|
# |   2371|        mazi-kun|      27|Trinity Blood|     5|
# |   2373|          Vortex|      27|Trinity Blood|     5|
# |   2388|           Revan|      27|Trinity Blood|     8|
# |   2392|          Renemu|      27|Trinity Blood|     9|
# |   2411|          WRYYYY|      27|Trinity Blood|     5|
# |   2412|    vanofthedawn|      27|Trinity Blood|     7|
# |   2423|           Azur4|      27|Trinity Blood|     7|
# |   2425|           Alwin|      27|Trinity Blood|     6|
# |   2435|     Prince_Mack|      27|Trinity Blood|     6|
# |   2442|          psy295|      27|Trinity Blood|     7|
# |   2448|          DaKeDo|      27|Trinity Blood|     8|
# |   2471|     angelcrisis|      27|Trinity Blood|     8|
# |   2473|        Link-kun|      27|Trinity Blood|     6|
# |   2477|             Lyn|      27|Trinity Blood|     7|
# |   2485|            Fena|      27|Trinity Blood|    10|
# |   2500|TheSoulAlchemist|      27|Trinity Blood|     8|
# |   2513|      ShiniSenko|      27|Trinity Blood|     6|
# |   2546|         OniNoKo|      27|Trinity Blood|     8|
# |   2548|            rins|      27|Trinity Blood|     7|
# |   2555|        Aneduune|      27|Trinity Blood|     8|
# |   2557| piecemealcranky|      27|Trinity Blood|     8|
# |   2564|KatyenkaSvetlana|      27|Trinity Blood|    10|
# |   2565|      Sinful-Des|      27|Trinity Blood|    10|
# |   2587|  TheRyuujinMike|      27|Trinity Blood|     6|
# |   2592|  penguinatorxl7|      27|Trinity Blood|     8|
# |   2605|            Lamy|      27|Trinity Blood|     8|
# |   2606|     Starwind824|      27|Trinity Blood|     6|
# |   2615|       lordjoker|      27|Trinity Blood|     8|
# |   2627|        Seiryoku|      27|Trinity Blood|     4|
# |   2635|         winnett|      27|Trinity Blood|     7|
# |   2674|       xpressemu|      27|Trinity Blood|     8|
# |   2677|           fanty|      27|Trinity Blood|     4|
# |   2680|            nn0r|      27|Trinity Blood|     3|
# |   2685|          Raijin|      27|Trinity Blood|     7|
# |   2696|            Zerg|      27|Trinity Blood|     8|
# |   2704|            Tanu|      27|Trinity Blood|     7|
# |   2738|           ejlan|      27|Trinity Blood|     8|
# |   2747|         requiem|      27|Trinity Blood|     9|
# |   2750|      dennis2049|      27|Trinity Blood|     7|
# |   2767|     Rulebreaker|      27|Trinity Blood|     7|
# |   2784|       ThePhr3ak|      27|Trinity Blood|     8|
# |   2812|     Loliplaya21|      27|Trinity Blood|     8|
# |   2816|            Pond|      27|Trinity Blood|     6|
# |   2842|           Janya|      27|Trinity Blood|     9|
# |   2872|          ssj2k4|      27|Trinity Blood|     8|
# |   2876|        watchman|      27|Trinity Blood|     5|
# |   2886|     MasterChief|      27|Trinity Blood|     9|
# |   2888|    jacen_solo15|      27|Trinity Blood|     5|
# |   2889|            Mew-|      27|Trinity Blood|     6|
# |   2897|    LadyCrysania|      27|Trinity Blood|     8|
# |   2903|           Hamel|      27|Trinity Blood|     7|
# |   2914|     Krembo_Chan|      27|Trinity Blood|     7|
# |   2919|        Jindrael|      27|Trinity Blood|     7|
# |   2941|         Foxtina|      27|Trinity Blood|    10|
# |   2942|       PureWater|      27|Trinity Blood|    10|
# |   2953|  SuperSmellyJoe|      27|Trinity Blood|     8|
# |   2959|  cinderella4221|      27|Trinity Blood|     8|
# |   2961|       Nosebleed|      27|Trinity Blood|     6|
# |   2963|            Upas|      27|Trinity Blood|     6|
# |   2969|        Digigirl|      27|Trinity Blood|    10|
# |   2999|     honeysempai|      27|Trinity Blood|    10|
# |   3001|         ReaVeRO|      27|Trinity Blood|     7|
# |   3005|          Kamira|      27|Trinity Blood|     8|
# |   3017|       PA_Shadow|      27|Trinity Blood|    10|
# |   3035|        shoot_me|      27|Trinity Blood|     8|
# |   3050|         alibama|      27|Trinity Blood|     8|
# |   3051|        gencbiba|      27|Trinity Blood|     7|
# |   3052|      WhiteGhost|      27|Trinity Blood|     8|
# |   3059|       TreeGreen|      27|Trinity Blood|     7|
# |   3088|           arntr|      27|Trinity Blood|     7|
# |   3096|         Suzanoo|      27|Trinity Blood|     7|
# |   3106|           Siing|      27|Trinity Blood|     4|
# |   3108|    shinobimisao|      27|Trinity Blood|     6|
# |   3119|         Psy-mon|      27|Trinity Blood|     5|
# |   3137|            S1LU|      27|Trinity Blood|     8|
# |   3146|      AtariJesus|      27|Trinity Blood|     7|
# |   3167|         D-Force|      27|Trinity Blood|    10|
# |   3172|            riki|      27|Trinity Blood|     7|
# |   3174|         Sarukah|      27|Trinity Blood|     7|
# |   3207|            tmth|      27|Trinity Blood|     7|
# |   3218|        jin_loen|      27|Trinity Blood|     7|
# |   3221|          amaity|      27|Trinity Blood|     7|
# |   3247|           Mueti|      27|Trinity Blood|     4|
# |   3250|    nymphetamine|      27|Trinity Blood|     8|
# |   3255|           Numed|      27|Trinity Blood|     9|
# |   3259|       Miroku205|      27|Trinity Blood|     6|
# |   3266|       Zer0Shift|      27|Trinity Blood|     7|
# |   3278|         CEMPUNK|      27|Trinity Blood|     7|
# |   3293|           ronno|      27|Trinity Blood|     7|
# |   3299|       megamalog|      27|Trinity Blood|     8|
# |   3313|       MoritaSan|      27|Trinity Blood|     8|
# |   3323|            qckZ|      27|Trinity Blood|     5|
# |   3338|    ero-sennin69|      27|Trinity Blood|     8|
# |   3343|        Millions|      27|Trinity Blood|     7|
# |   3359|    lord_shaolin|      27|Trinity Blood|     8|
# |   3385|     neko-ka-san|      27|Trinity Blood|     6|
# |   3386|      eichi-sama|      27|Trinity Blood|     6|
# |   3390|         Echolon|      27|Trinity Blood|     8|
# |   3409|        Aerineth|      27|Trinity Blood|     5|
# |   3421|     Shadowblitz|      27|Trinity Blood|     7|
# |   3426|      ChibiAyane|      27|Trinity Blood|     5|
# |   3427|         theSage|      27|Trinity Blood|     5|
# |   3444|    purplehikari|      27|Trinity Blood|    10|
# |   3457|     crystal_yuy|      27|Trinity Blood|     7|
# |   3467|          CheeZe|      27|Trinity Blood|     8|
# |   3494|   mysticdreamer|      27|Trinity Blood|     6|
# |   3495|     tammy151507|      27|Trinity Blood|     6|
# |   3511|         Gamicon|      27|Trinity Blood|     9|
# |   3512|        Lawlliet|      27|Trinity Blood|     7|
# |   3514|       Damoizgod|      27|Trinity Blood|    10|
# |   3524|           lgmtk|      27|Trinity Blood|     6|
# |   3532|        Sakura__|      27|Trinity Blood|     8|
# |   3556|           taalu|      27|Trinity Blood|     8|
# |   3568|    justaddScott|      27|Trinity Blood|     7|
# |   3578|      mangafreak|      27|Trinity Blood|     4|
# |   3603|       otakukidd|      27|Trinity Blood|     5|
# |   3615|         smubeht|      27|Trinity Blood|     8|
# |   3626|        pyro8562|      27|Trinity Blood|    10|
# |   3629|        Neophyte|      27|Trinity Blood|     7|
# |   3637|         noelhoi|      27|Trinity Blood|     7|
# |   3654|     LadyMikayla|      27|Trinity Blood|     9|
# |   3661|         Tsunami|      27|Trinity Blood|     8|
# |   3663|        Arseylah|      27|Trinity Blood|     7|
# |   3679|      seriossebi|      27|Trinity Blood|     4|
# |   3685|           zwr33|      27|Trinity Blood|     6|
# |   3707|         Xaiphin|      27|Trinity Blood|    10|
# |   3723|            ApoC|      27|Trinity Blood|     9|
# |   3724|    UltimaHunter|      27|Trinity Blood|     8|
# |   3749|      VeryEvilDr|      27|Trinity Blood|     9|
# |   3750|            Biba|      27|Trinity Blood|     7|
# |   3759|         Tagnard|      27|Trinity Blood|     9|
# |   3760|     Landstander|      27|Trinity Blood|     4|
# |   3777|       MephDaddy|      27|Trinity Blood|     7|
# |   3784|            Cain|      27|Trinity Blood|     8|
# |   3799|         Mitheel|      27|Trinity Blood|     8|
# |   3815|     Bluedragoon|      27|Trinity Blood|     7|
# |   3834|       Nightwish|      27|Trinity Blood|     9|
# |   3840|          hoseki|      27|Trinity Blood|     7|
# |   3867|          rictys|      27|Trinity Blood|     7|
# |   3874|          akiteo|      27|Trinity Blood|     7|
# |   3878|       DeathNote|      27|Trinity Blood|     8|
# |   3886|      mitamaking|      27|Trinity Blood|     4|
# |   3887|          Najica|      27|Trinity Blood|     5|
# |   3892|          Gothai|      27|Trinity Blood|     4|
# |   3907|       KingCloud|      27|Trinity Blood|     7|
# |   3923|        Fettgans|      27|Trinity Blood|     5|
# |   3926|   sakurachi2004|      27|Trinity Blood|     6|
# |   3945|          Fyndra|      27|Trinity Blood|     6|
# |   3952|      houndtooth|      27|Trinity Blood|     8|
# |   3962|        kammerer|      27|Trinity Blood|     6|
# |   3967|          tolete|      27|Trinity Blood|     9|
# |   3969|        __PAUL__|      27|Trinity Blood|     8|
# |   3977|         pudding|      27|Trinity Blood|     9|
# |   4023|           Rowan|      27|Trinity Blood|     5|
# |   4035|         fatalis|      27|Trinity Blood|     6|
# |   4036| xdarksideangelx|      27|Trinity Blood|     9|
# |   4045|           binio|      27|Trinity Blood|     7|
# |   4055|       satoupaku|      27|Trinity Blood|     8|
# |   4070|      missing592|      27|Trinity Blood|     7|
# |   4093|      Darkzeross|      27|Trinity Blood|     6|
# |   4094|    Avitar_Diggs|      27|Trinity Blood|     5|
# |   4111|  alchemyangel11|      27|Trinity Blood|     9|
# |   4124|           Yunie|      27|Trinity Blood|     7|
# |   4137|        DarkDays|      27|Trinity Blood|     8|
# |   4140|        graywolf|      27|Trinity Blood|     4|
# |   4160|              Sg|      27|Trinity Blood|    10|
# |   4163|        Hitman66|      27|Trinity Blood|     8|
# |   4199|         Unknown|      27|Trinity Blood|     5|
# |   4208|    garu_daisuki|      27|Trinity Blood|     9|
# |   4242|           Eamon|      27|Trinity Blood|     7|
# |   4243|             Moi|      27|Trinity Blood|     7|
# |   4254|     LordAwesome|      27|Trinity Blood|    10|
# |   4256|     Shadow-Chan|      27|Trinity Blood|     9|
# |   4285|          pierro|      27|Trinity Blood|     7|
# |   4305|       f0calizer|      27|Trinity Blood|     6|
# |   4327|           snork|      27|Trinity Blood|     8|
# |   4330|        ZephyrSB|      27|Trinity Blood|     4|
# |   4344|       Darkanger|      27|Trinity Blood|     9|
# |   4350|         easymac|      27|Trinity Blood|     9|
# |   4353|       elenuvien|      27|Trinity Blood|     9|
# |   4363|             Eax|      27|Trinity Blood|     6|
# |   4372|        HerMioNe|      27|Trinity Blood|     8|
# |   4396|          kiruka|      27|Trinity Blood|     8|
# |   4405|     KurosakiKun|      27|Trinity Blood|     9|
# |   4407|          ExoDus|      27|Trinity Blood|     6|
# |   4413|          Nines_|      27|Trinity Blood|     7|
# |   4417|            TAoF|      27|Trinity Blood|     8|
# |   4456|   hellsdemonica|      27|Trinity Blood|     8|
# |   4457|          verite|      27|Trinity Blood|     7|
# |   4460|   InoueKurosaki|      27|Trinity Blood|    10|
# |   4462|       Stinger02|      27|Trinity Blood|     8|
# |   4479|              Dr|      27|Trinity Blood|     7|
# |   4480|           Keogh|      27|Trinity Blood|     8|
# |   4488|             zed|      27|Trinity Blood|     9|
# |   4497|         Xyanide|      27|Trinity Blood|     6|
# |   4503|           dacon|      27|Trinity Blood|     3|
# |   4504|        Shanatan|      27|Trinity Blood|     8|
# |   4506|         aeraeon|      27|Trinity Blood|     7|
# |   4507|         Calau90|      27|Trinity Blood|     8|
# |   4510|       BzzzYczeK|      27|Trinity Blood|    10|
# |   4542|           shana|      27|Trinity Blood|     8|
# |   4543|            Seth|      27|Trinity Blood|     8|
# |   4568|         Reshaim|      27|Trinity Blood|     8|
# |   4570|          HuSSaR|      27|Trinity Blood|     7|
# |   4583|    jocejoce1001|      27|Trinity Blood|    10|
# |   4591|              JT|      27|Trinity Blood|     3|
# |   4653|        Kajitoku|      27|Trinity Blood|     8|
# |   4665|     blissinator|      27|Trinity Blood|     7|
# |   4678|           okami|      27|Trinity Blood|     7|
# |   4689|       villy_100|      27|Trinity Blood|     9|
# |   4690|             TAB|      27|Trinity Blood|     8|
# |   4699|          Sayuri|      27|Trinity Blood|     8|
# |   4703|            Abel|      27|Trinity Blood|     9|
# |   4727|     mingoshingo|      27|Trinity Blood|     7|
# |   4734|        RedGriff|      27|Trinity Blood|     7|
# |   4737|           lepen|      27|Trinity Blood|     8|
# |   4747|     estuardogon|      27|Trinity Blood|     9|
# |   4765|         inugami|      27|Trinity Blood|     8|
# |   4779|      DarkSorrow|      27|Trinity Blood|    10|
# |   4825|         Saizoku|      27|Trinity Blood|     7|
# |   4830|     cookie-chan|      27|Trinity Blood|     8|
# |   4832|         kurropt|      27|Trinity Blood|     7|
# |   4837|      MizuNoKiba|      27|Trinity Blood|     7|
# |   4846|        NekoIssa|      27|Trinity Blood|     8|
# |   4852|         Tsakkun|      27|Trinity Blood|     9|
# |   4858|    Mitsuki-chan|      27|Trinity Blood|     9|
# |   4861|  mada_mada_dane|      27|Trinity Blood|     8|
# |   4864|            me0w|      27|Trinity Blood|     7|
# |   4865|          Terran|      27|Trinity Blood|     6|
# |   4866|          Raizen|      27|Trinity Blood|     7|
# |   4879|         rayne04|      27|Trinity Blood|    10|
# |   4887|          Erutis|      27|Trinity Blood|     9|
# |   4905| kurayami_kyouko|      27|Trinity Blood|     7|
# |   4910|        banglaCM|      27|Trinity Blood|     4|
# |   4917|    fall3nstar84|      27|Trinity Blood|     6|
# |   4918|          julian|      27|Trinity Blood|     7|
# |   4919|        KiddWolf|      27|Trinity Blood|     6|
# |   4923|  sesshylvr4ever|      27|Trinity Blood|     9|
# |   4934|    GambitBladeX|      27|Trinity Blood|     5|
# |   4938|    madexinxhell|      27|Trinity Blood|    10|
# |   4941|   andgitfullice|      27|Trinity Blood|     8|
# |   4951|      Cloudrayne|      27|Trinity Blood|     7|
# |   4953|   ibreatheanime|      27|Trinity Blood|     5|
# |   4987|            ryos|      27|Trinity Blood|     9|
# |   4998|      tigeress02|      27|Trinity Blood|     8|
# |   5016|         Astraea|      27|Trinity Blood|     7|
# |   5018|   xxdeadpeacexx|      27|Trinity Blood|     9|
# |   5019|         Zalmari|      27|Trinity Blood|     7|
# |   5034|        xxyumexx|      27|Trinity Blood|     5|
# |   5037|          Shikyo|      27|Trinity Blood|     6|
# |   5042|            x207|      27|Trinity Blood|     7|
# |   5043|            Izzo|      27|Trinity Blood|     3|
# |   5055|          Nuriko|      27|Trinity Blood|     9|
# |   5061|      exile_dude|      27|Trinity Blood|     6|
# |   5071|      pandapanda|      27|Trinity Blood|    10|
# |   5084|       midnighty|      27|Trinity Blood|    10|
# |   5097|      Ai-Haibara|      27|Trinity Blood|     1|
# |   5103|          FMA133|      27|Trinity Blood|    10|
# |   5113|       seiya1331|      27|Trinity Blood|     5|
# |   5148|       Omni-kyun|      27|Trinity Blood|     5|
# |   5154|     jupiterjazz|      27|Trinity Blood|     6|
# |   5174|  kage_ookami197|      27|Trinity Blood|     8|
# |   5175|       WhiteMage|      27|Trinity Blood|    10|
# |   5182|       Champagne|      27|Trinity Blood|    10|
# |   5183|       Misa-Misa|      27|Trinity Blood|     7|
# |   5224|      NamelessMC|      27|Trinity Blood|    10|
# |   5232|      Kuroi_Ishi|      27|Trinity Blood|     8|
# |   5242|    apocalipsysv|      27|Trinity Blood|     9|
# |   5245|        discbabe|      27|Trinity Blood|    10|
# |   5248|           Uzeal|      27|Trinity Blood|     7|
# |   5259|          Dauthi|      27|Trinity Blood|     7|
# |   5266|        DarkLink|      27|Trinity Blood|     6|
# |   5268|         Daverto|      27|Trinity Blood|     7|
# |   5270|           egura|      27|Trinity Blood|     9|
# |   5272|         FreaKaZ|      27|Trinity Blood|     6|
# |   5276|       spaceneko|      27|Trinity Blood|     6|
# |   5277|          Duryel|      27|Trinity Blood|     9|
# |   5279|        Meltdown|      27|Trinity Blood|     7|
# |   5281|       BeanyBear|      27|Trinity Blood|     8|
# |   5298|          nikora|      27|Trinity Blood|     9|
# |   5309| detestedlove311|      27|Trinity Blood|     6|
# |   5326| LeChevalierNoir|      27|Trinity Blood|     7|
# |   5341|        Spawnfan|      27|Trinity Blood|     9|
# |   5350|         sanzoki|      27|Trinity Blood|     7|
# |   5352|           Maffy|      27|Trinity Blood|     7|
# |   5363|   neko_chan1987|      27|Trinity Blood|     8|
# |   5368|        HimawaRi|      27|Trinity Blood|     7|
# |   5375|GIlgameshxIshtar|      27|Trinity Blood|    10|
# |   5383|           2DIE4|      27|Trinity Blood|     8|
# |   5416|      thunder_xx|      27|Trinity Blood|     4|
# |   5449|       seraphire|      27|Trinity Blood|     7|
# |   5458|             K_N|      27|Trinity Blood|     7|
# |   5468|           Ruzio|      27|Trinity Blood|     8|
# |   5469|           yendi|      27|Trinity Blood|     8|
# |   5499|         neotran|      27|Trinity Blood|     9|
# |   5501|    LilPearlBaby|      27|Trinity Blood|     9|
# |   5514|        solid002|      27|Trinity Blood|     5|
# |   5524|          Alokat|      27|Trinity Blood|     6|
# |   5527| darkschneider20|      27|Trinity Blood|     9|
# |   5529|             Wes|      27|Trinity Blood|     8|
# |   5545|          Kryxuz|      27|Trinity Blood|     8|
# |   5557|SesshomaruKatana|      27|Trinity Blood|     8|
# |   5571|        Armandas|      27|Trinity Blood|     5|
# |   5588|           suran|      27|Trinity Blood|     3|
# |   5593|   Godofdarkness|      27|Trinity Blood|    10|
# |   5594|           Arwym|      27|Trinity Blood|     9|
# |   5618|           Urisk|      27|Trinity Blood|     7|
# |   5628|    DanceAngel18|      27|Trinity Blood|     6|
# |   5630|       Tachi-Kun|      27|Trinity Blood|     9|
# |   5636|            tarf|      27|Trinity Blood|     8|
# |   5641|       incognito|      27|Trinity Blood|     7|
# |   5642|            Slin|      27|Trinity Blood|     3|
# |   5644|           tilde|      27|Trinity Blood|    10|
# |   5653|        Akuma147|      27|Trinity Blood|     7|
# |   5664|           dioma|      27|Trinity Blood|     7|
# |   5665|        insengue|      27|Trinity Blood|     7|
# |   5669|       Knight613|      27|Trinity Blood|     7|
# |   5670|      Extirpator|      27|Trinity Blood|     7|
# |   5682|          hitomi|      27|Trinity Blood|     7|
# |   5703|       SquallAce|      27|Trinity Blood|     7|
# |   5710|           Zarum|      27|Trinity Blood|     6|
# |   5734|          ashura|      27|Trinity Blood|     7|
# |   5750|         Burasto|      27|Trinity Blood|     6|
# |   5752|    ReDdIcLoNiUs|      27|Trinity Blood|    10|
# |   5761|      Hraesvelgr|      27|Trinity Blood|     2|
# |   5777|       turbonutn|      27|Trinity Blood|     8|
# |   5788|         francis|      27|Trinity Blood|    10|
# |   5789|        polonius|      27|Trinity Blood|     6|
# |   5794|            ares|      27|Trinity Blood|     7|
# |   5796|        lenquist|      27|Trinity Blood|     6|
# |   5807|      eirarangel|      27|Trinity Blood|     7|
# |   5814|        Krysalis|      27|Trinity Blood|    10|
# |   5818|        PsyGriff|      27|Trinity Blood|     8|
# |   5828|            Raja|      27|Trinity Blood|     7|
# |   5840|  crazedanimefan|      27|Trinity Blood|    10|
# |   5841|    KawaiiLolita|      27|Trinity Blood|     9|
# |   5845|           SpawN|      27|Trinity Blood|     7|
# |   5847|      nerdypants|      27|Trinity Blood|     4|
# |   5854|      gaiascully|      27|Trinity Blood|     4|
# |   5859|         riraito|      27|Trinity Blood|     8|
# |   5869|         Rainy29|      27|Trinity Blood|     4|
# |   5876|           ixnay|      27|Trinity Blood|     7|
# |   5879|   angelprincess|      27|Trinity Blood|     9|
# |   5881|        Char_543|      27|Trinity Blood|     3|
# |   5884|          obidos|      27|Trinity Blood|     5|
# |   5889|    spiralsraise|      27|Trinity Blood|     8|
# |   5900|           Cille|      27|Trinity Blood|     4|
# |   5902|      enyce42nyc|      27|Trinity Blood|     7|
# |   5907|      kingheart3|      27|Trinity Blood|     7|
# |   5914|            F0RR|      27|Trinity Blood|     7|
# |   5918|       Meatbag42|      27|Trinity Blood|     9|
# |   5922|         Pittaxx|      27|Trinity Blood|     9|
# |   5947|          zabbyh|      27|Trinity Blood|     6|
# |   5957|       MetatronM|      27|Trinity Blood|     3|
# |   5967|   Torpidshadows|      27|Trinity Blood|    10|
# |   5979|  Lynk-Harkonnen|      27|Trinity Blood|     8|
# |   5998|         orange-|      27|Trinity Blood|     8|
# |   6016|      DesertRose|      27|Trinity Blood|    10|
# |   6052|         Eruanna|      27|Trinity Blood|     8|
# |   6058|       nakashima|      27|Trinity Blood|     7|
# |   6094|       lovlyneko|      27|Trinity Blood|     7|
# |   6099|       haru-chan|      27|Trinity Blood|     8|
# |   6102|     kawaii_kupo|      27|Trinity Blood|     8|
# |   6104|          4anime|      27|Trinity Blood|     7|
# |   6111|     tastylizard|      27|Trinity Blood|     5|
# |   6140|       trafagibr|      27|Trinity Blood|     8|
# |   6175|    vampires_key|      27|Trinity Blood|     8|
# |   6189|          hikura|      27|Trinity Blood|     7|
# |   6205|         zorozin|      27|Trinity Blood|     9|
# |   6207|   Darkwolftears|      27|Trinity Blood|     9|
# |   6216|  RecursiveGreen|      27|Trinity Blood|     6|
# |   6220|         jayekin|      27|Trinity Blood|     7|
# |   6235|   YoshikoHatake|      27|Trinity Blood|    10|
# |   6254|          davidb|      27|Trinity Blood|     6|
# |   6261|        dexter89|      27|Trinity Blood|     7|
# |   6264|          edwarx|      27|Trinity Blood|     5|
# |   6271|      smithiea21|      27|Trinity Blood|     7|
# |   6279|        zawmintu|      27|Trinity Blood|     7|
# |   6281|       Celestial|      27|Trinity Blood|     7|
# |   6292|      mtthefirst|      27|Trinity Blood|     8|
# |   6301|          Tuomiz|      27|Trinity Blood|     9|
# |   6302|     NairaKitara|      27|Trinity Blood|     9|
# |   6317|   Vampire-Panda|      27|Trinity Blood|     8|
# |   6318|       123456sdf|      27|Trinity Blood|     8|
# |   6323|        Nexus___|      27|Trinity Blood|    10|
# |   6325|      DeadlyRain|      27|Trinity Blood|    10|
# |   6332|      Silverberg|      27|Trinity Blood|     6|
# |   6334|        gooooone|      27|Trinity Blood|     6|
# |   6337|             zlq|      27|Trinity Blood|     9|
# |   6397|       chaosash3|      27|Trinity Blood|     7|
# |   6426|    Deceptive621|      27|Trinity Blood|     9|
# |   6436|       AnimeMatt|      27|Trinity Blood|     9|
# |   6441|      Ithilariel|      27|Trinity Blood|     9|
# |   6447|         evolove|      27|Trinity Blood|     7|
# |   6449|      Ahojcookie|      27|Trinity Blood|     6|
# |   6452|          Haavve|      27|Trinity Blood|     8|
# |   6456|      MitchDaMan|      27|Trinity Blood|     4|
# |   6459|      dkaceblaze|      27|Trinity Blood|     9|
# |   6481|   GuitarPhoenix|      27|Trinity Blood|     7|
# |   6485|          ksl269|      27|Trinity Blood|     7|
# |   6486|iwatch2muchanime|      27|Trinity Blood|     6|
# |   6494|       Shurtugal|      27|Trinity Blood|     8|
# |   6495|      MoonxChild|      27|Trinity Blood|     8|
# |   6508|        volition|      27|Trinity Blood|     8|
# |   6511|      MasterFang|      27|Trinity Blood|     8|
# |   6545| way_to_obsessed|      27|Trinity Blood|     8|
# |   6603|        topzki47|      27|Trinity Blood|     7|
# |   6608|        Legion17|      27|Trinity Blood|     9|
# |   6610|  Alastourblaque|      27|Trinity Blood|     5|
# |   6612|           kdawg|      27|Trinity Blood|     2|
# |   6624|          Fefedf|      27|Trinity Blood|     2|
# |   6628|         bherman|      27|Trinity Blood|     9|
# |   6629|CelestialEmpress|      27|Trinity Blood|     4|
# |   6631|        Punisher|      27|Trinity Blood|     9|
# |   6640|        Redrocky|      27|Trinity Blood|     8|
# |   6660|          barrel|      27|Trinity Blood|     6|
# |   6671|         Zeto2k1|      27|Trinity Blood|     9|
# |   6675|    ShadowStaarr|      27|Trinity Blood|     3|
# |   6676|    SweetlyKaoru|      27|Trinity Blood|     7|
# |   6679|    MasterSamson|      27|Trinity Blood|     3|
# |   6683|    BigBagODicks|      27|Trinity Blood|     4|
# |   6693|      sappho1990|      27|Trinity Blood|     7|
# |   6694|   CowboyCadenza|      27|Trinity Blood|     3|
# |   6695|  captain-le-fou|      27|Trinity Blood|     6|
# +-------+----------------+--------+-------------+------+
# only showing top 1000 rows

# %%
spark.sql("select rating, count(*)  from iceberg.db.anime_users_score where rating > 7 group by rating").show(100)
# Out:
# [Stage 6:=====================================================> (264 + 9) / 273]
# +------+--------+
# |rating|count(1)|
# +------+--------+
# |     9|  174750|
# |     8|  259153|
# |    10|  111958|
# +------+--------+

# %%
spark.sql("select count(*)  from iceberg.db.anime_users_score where anime_title = 'One Piece'").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |    2182|
# +--------+

# %% [markdown]
# # Updating records

# %%
spark.sql("update iceberg.db.anime_users_score set anime_title = 'One_Piece' where anime_title='One Piece'")
# Out:
# DataFrame[]

# %%
spark.sql("select count(*)  from iceberg.db.anime_users_score where anime_title = 'One_Piece'").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |    2182|
# +--------+

# %%
spark.sql("select count(*)  from iceberg.db.anime_users_score where anime_id = 21").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |    2182|
# +--------+

# %% [markdown]
# # Inspecting our table

# %%
df=spark.sql("SELECT * FROM iceberg.db.my_table.history")
df.show()
df.write.save("/Users/anshumanr/Documents/Iceberg/Apache_iceberg/iceberg-warehouse/db/anime_users_score/history",header=True)
# Out:
# +--------------------+-------------------+-------------------+-------------------+
# |     made_current_at|        snapshot_id|          parent_id|is_current_ancestor|
# +--------------------+-------------------+-------------------+-------------------+
# |2023-08-11 18:07:...|2936313136471033108|               null|               true|
# |2023-08-11 18:07:...|4480161109182211569|2936313136471033108|               true|
# |2023-08-11 18:07:...| 925325890966312565|4480161109182211569|               true|
# |2023-08-11 18:07:...|8852684860612151750| 925325890966312565|               true|
# +--------------------+-------------------+-------------------+-------------------+

# %%
df=spark.sql("SELECT * FROM iceberg.db.my_table.snapshots")
df.show()
df.write.save("/Users/anshumanr/Documents/Iceberg/Apache_iceberg/iceberg-warehouse/db/anime_users_score/snapshots",header=True)
# Out:
# +--------------------+-------------------+-------------------+---------+--------------------+--------------------+
# |        committed_at|        snapshot_id|          parent_id|operation|       manifest_list|             summary|
# +--------------------+-------------------+-------------------+---------+--------------------+--------------------+
# |2023-08-11 18:07:...|2936313136471033108|               null|   append|iceberg-warehouse...|{spark.app.id -> ...|
# |2023-08-11 18:07:...|4480161109182211569|2936313136471033108|overwrite|iceberg-warehouse...|{spark.app.id -> ...|
# |2023-08-11 18:07:...| 925325890966312565|4480161109182211569|   append|iceberg-warehouse...|{spark.app.id -> ...|
# |2023-08-11 18:07:...|8852684860612151750| 925325890966312565|overwrite|iceberg-warehouse...|{spark.app.id -> ...|
# +--------------------+-------------------+-------------------+---------+--------------------+--------------------+

# %%
df=spark.sql("SELECT * FROM iceberg.db.my_table.files")
df.show()
df.write.save("/Users/anshumanr/Documents/Iceberg/Apache_iceberg/iceberg-warehouse/db/anime_users_score/files",header=True)
# Out:
# +-------+--------------------+-----------+-------+------------+------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+------------+-------------+------------+-------------+--------------------+
# |content|           file_path|file_format|spec_id|record_count|file_size_in_bytes|        column_sizes|        value_counts|   null_value_counts|nan_value_counts|        lower_bounds|        upper_bounds|key_metadata|split_offsets|equality_ids|sort_order_id|    readable_metrics|
# +-------+--------------------+-----------+-------+------------+------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+------------+-------------+------------+-------------+--------------------+
# |      0|iceberg-warehouse...|    PARQUET|      0|           1|               976|{1 -> 55, 2 -> 51...|{1 -> 1, 2 -> 1, ...|{1 -> 0, 2 -> 0, ...|              {}|{1 -> Alex, 2 -> ...|{1 -> Alex, 2 -> ...|        null|          [4]|        null|            0|{{51, 1, 0, null,...|
# |      0|iceberg-warehouse...|    PARQUET|      0|           1|               970|{1 -> 51, 2 -> 47...|{1 -> 1, 2 -> 1, ...|{1 -> 0, 2 -> 0, ...|              {}|{1 -> John, 2 -> ...|{1 -> John, 2 -> ...|        null|          [4]|        null|            0|{{47, 1, 0, null,...|
# |      0|iceberg-warehouse...|    PARQUET|      0|           1|               636|  {1 -> 50, 2 -> 47}|    {1 -> 1, 2 -> 1}|    {1 -> 0, 2 -> 0}|              {}|{1 -> Bob, 2 -> ...|{1 -> Bob, 2 -> ...|        null|          [4]|        null|            0|{{47, 1, 0, null,...|
# |      0|iceberg-warehouse...|    PARQUET|      0|           1|               650|  {1 -> 52, 2 -> 47}|    {1 -> 1, 2 -> 1}|    {1 -> 0, 2 -> 0}|              {}|{1 -> Fiona, 2 ->...|{1 -> Fiona, 2 ->...|        null|          [4]|        null|            0|{{47, 1, 0, null,...|
# |      0|iceberg-warehouse...|    PARQUET|      0|           1|               650|  {1 -> 52, 2 -> 47}|    {1 -> 1, 2 -> 1}|    {1 -> 0, 2 -> 0}|              {}|{1 -> Roger, 2 ->...|{1 -> Roger, 2 ->...|        null|          [4]|        null|            0|{{47, 1, 0, null,...|
# +-------+--------------------+-----------+-------+------------+------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+------------+-------------+------------+-------------+--------------------+

# %%
df=spark.sql("SELECT * FROM iceberg.db.my_table.manifests")
df.show()
df.write.save("/Users/anshumanr/Documents/Iceberg/Apache_iceberg/iceberg-warehouse/db/anime_users_score/manifests",header=True)
# Out:
# +-------+--------------------+------+-----------------+-------------------+----------------------+-------------------------+------------------------+------------------------+---------------------------+--------------------------+-------------------+
# |content|                path|length|partition_spec_id|  added_snapshot_id|added_data_files_count|existing_data_files_count|deleted_data_files_count|added_delete_files_count|existing_delete_files_count|deleted_delete_files_count|partition_summaries|
# +-------+--------------------+------+-----------------+-------------------+----------------------+-------------------------+------------------------+------------------------+---------------------------+--------------------------+-------------------+
# |      0|iceberg-warehouse...|  5852|                0|8852684860612151750|                     1|                        0|                       0|                       0|                          0|                         0|                 []|
# |      0|iceberg-warehouse...|  5850|                0| 925325890966312565|                     1|                        0|                       0|                       0|                          0|                         0|                 []|
# |      0|iceberg-warehouse...|  5830|                0|8852684860612151750|                     0|                        0|                       1|                       0|                          0|                         0|                 []|
# |      0|iceberg-warehouse...|  5855|                0|4480161109182211569|                     0|                        3|                       1|                       0|                          0|                         0|                 []|
# +-------+--------------------+------+-----------------+-------------------+----------------------+-------------------------+------------------------+------------------------+---------------------------+--------------------------+-------------------+

# %%
df=spark.sql("SELECT * FROM iceberg.db.my_table.partitions")
df.show()
df.write.save("/Users/anshumanr/Documents/Iceberg/Apache_iceberg/iceberg-warehouse/db/anime_users_score/partitions",header=True)
# Out:
# +------------+----------+----------------------------+--------------------------+----------------------------+--------------------------+
# |record_count|file_count|position_delete_record_count|position_delete_file_count|equality_delete_record_count|equality_delete_file_count|
# +------------+----------+----------------------------+--------------------------+----------------------------+--------------------------+
# |           5|         5|                           0|                         0|                           0|                         0|
# +------------+----------+----------------------------+--------------------------+----------------------------+--------------------------+
